# %%
import pandas as pd

# %%
df = pd.read_csv('sven_plants.csv')

# %%
df
# Out:
#             Family      Genus       Species  \
# 0     Marsileaceae   Marsilea    drummondii
# 1      Ephedraceae    Ephedra     distachya
# 2      Ephedraceae    Ephedra    nevadensis
# 3      Ephedraceae    Ephedra       viridis
# 4    Araucariaceae  Araucaria  angustifolia
# ..             ...        ...           ...
# 847      Aceraceae       Acer       negundo
# 848      Aceraceae       Acer   platanoides
# 849      Aceraceae       Acer        rubrum
# 850      Aceraceae       Acer     saccharum
# 851      Aceraceae       Acer   saccharinum
#
#                                             CommonName GrowthRate  \
# 0                                Common Nardoo, Nardoo        NaN
# 1                                  Sea Grape, Jointfir        NaN
# 2                          Mormon Tea, Nevada jointfir        NaN
# 3    Mormon Tea, Brigham Tea, Long Leaf Ephedra, Mo...        NaN
# 4        Parana Pine. Brazilian-pine, Candelabra-tree.       slow
# ...
