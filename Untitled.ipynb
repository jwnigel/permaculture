# %%
import pandas as pd
df = pd.read_csv('plants.csv')

# %%
df
# Out:
#                         Family         Genus        Species  \
# 0                    Aceraceae          Acer    saccharinum
# 1                    Aceraceae          Acer      saccharum
# 2     Asteraceae or Compositae      Achillea    millefolium
# 3     Asteraceae or Compositae      Achillea       ptarmica
# 4                Actinidiaceae     Actinidia         arguta
# 5                Actinidiaceae     Actinidia       purpurea
# 6        Lamiaceae or Labiatae     Agastache     foeniculum
# 7                    Malvaceae         Alcea          rosea
# 8                    Alliaceae        Allium      canadense
# 9                    Alliaceae        Allium      tricoccum
# 10                  Betulaceae         Alnus        cordata
# 11                  Betulaceae         Alnus      serrulata
# 12     Fabaceae or Leguminosae       Amorpha      fruticosa
# 13     Fabaceae or Leguminosae  Amphicarpaea      bracteata
# 14     Fabaceae or Leguminosae         Apios      americana
# ...
